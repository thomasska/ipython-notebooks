# %% [markdown]
# AR1 plotting - 12 October
# =============
# Scripts to plot the first results from AR1.  These files are generated by Sean's signal-generator script.
# <script type="text/javascript">
#     show=true;
#     function toggle(){
#         if (show){
#             $('div.input').hide();
#         }else{
#             $('div.input').show();
#         }
#         show = !show
#     }
# </script>
# <a href="javascript:toggle()" target="_self">Click here to toggle the code cells</a>
#
# Links: [Signal displays](http://sdp-ingest4.kat.ac.za:8000/)  and  [Archive Search](http://kat-archive.kat.ac.za:8983/archive_search/)
#
#
# Made with one digitiser connected to:
#
# * Noise source. (filtered for 70-300 MHz or so).  Attenuator setting: 10 dB.
# * Signal generator, attenuator 30 dB.  Controlled by Sean's obs script.
# * Digitiser cables: equal length cables connected to the digitiser

# %%
# useful cell to produce frequency stepping instructions for a long every-channel test
chStart = 0;
chStop = 4095.001;
chSteps = 1;

print("use this string:     --siggen-freq='%10.6f,%10.6f,%9.6f'" % ( (4096-chStart)*856.0/4096.0, (4096-chStop)*856.0/4096.0, -chSteps*856.0/4096.0) );
numSteps = (chStop-chStart)/chSteps + 1;
print("total of %f steps, which will take about %i minutes" % ( numSteps, 5*numSteps/60 ) )
# Out:
# use this string:     --siggen-freq='856.000000,  0.208775,-0.208984'
# total of 4096.001000 steps, which will take about 341 minutes

# %%
# useful cell to produce frequency stepping instructions for TP1.1.3 test2
chStart = 99;
chStop = 3999.05;
chSteps = 13;

print("use this string:     --siggen-freq='%10.6f,%10.6f,%9.6f'" % ( (4096-chStart)*856.0/4096.0, (4096-chStop)*856.0/4096.0, -chSteps*856.0/4096.0) );
numSteps = (chStop-chStart)/chSteps + 1;
print("total of %f steps, which will take about %i minutes" % ( numSteps, 5*numSteps/60 ) )
# Out:
# use this string:     --siggen-freq='835.310547, 20.261035,-2.716797'
# total of 301.003846 steps, which will take about 25 minutes

# %%
# useful cell to produce frequency stepping instructions for TP1.1.3 test4
chStart = 1360;
chStop = 1361.51;
chSteps = 0.5;

print("use this string:     --siggen-freq='%10.6f,%10.6f,%9.6f'" % ( (4096-chStart)*856.0/4096.0, (4096-chStop)*856.0/4096.0, -chSteps*856.0/4096.0) );
numSteps = (chStop-chStart)/chSteps + 1;
print("total of %f steps, which will take about %i minutes" % ( numSteps, 5*numSteps/60 ) )
# Out:
# use this string:     --siggen-freq='571.781250,571.465684,-0.104492'
# total of 4.020000 steps, which will take about 0 minutes

# %%
# useful cell to produce frequency stepping instructions for TP1.1.4
chStart = 300;
chStop = 3600.1;
chSteps = (3600-300)/12;

print("use this string:     --siggen-freq='%10.6f,%10.6f,%9.6f'" % ( (4096-chStart)*856.0/4096.0, (4096-chStop)*856.0/4096.0, -chSteps*856.0/4096.0) );
numSteps = (chStop-chStart)/chSteps + 1;
print("total of %f steps, which will take about %i minutes" % ( numSteps, 5*numSteps/60 ) )
# Out:
# use this string:     --siggen-freq='793.304688,103.635352,-57.470703'
# total of 13.000364 steps, which will take about 1 minutes

# %% [markdown]
# 1. Steady power test
# ===================

# %%
import katdal, numpy as np, matplotlib
D=katdal.open('/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/13/1444729458.h5');     # steady power. Signal and noise. (Replace with 120 second one when it's ready)
D.select()
D.select(compscans='~transition')
# Out:
# WARNING:katdal.h5datav3:Irregular timestamps detected in file '/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/13/1444729458.h5': expected 121.000 dumps based on dump period and start/end times, got 61 instead

# %%
# autocorrelations
t=10;
figure(figsize=(12,2))
plot(10*log10(abs(squeeze(D.vis[t,:,0]))),label=D.corr_products[0])
plot(10*log10(abs(squeeze(D.vis[t,:,1]))),label=D.corr_products[1])
title('Autocorrelation baselines of %s over channel at t=%i' % (D.experiment_id,t)); xlabel('Channel');  ylabel('Correlator power, dBarbitrary'); xlim([0,4095]);  legend(loc=0);

ch=1360;
figure(figsize=(12,2))
plot(10*log10(abs(squeeze(D.vis[:,ch,0]))),label=D.corr_products[0])
plot(10*log10(abs(squeeze(D.vis[:,ch,1]))),label=D.corr_products[1])
title('Autocorrelation baselines of %s over time at channel=%i'% (D.experiment_id,ch)); xlabel('Dump');  ylabel('Correlator power, dBarbitrary');  legend(loc=0);

# %%
# cross correlations
t=10;
figure(figsize=(12,2))
plot(10*log10(abs(squeeze(D.vis[t,:,2]))),label=D.corr_products[2])
title('Cross-correlation baselines of %s over channel at t=%i' % (D.experiment_id,t)); xlabel('Channel');  ylabel('Correlator power, dBarbitrary'); xlim([0,4095]);  legend(loc=0);
figure(figsize=(12,2))
plot(angle(squeeze(D.vis[t,:,2])),label=D.corr_products[2])
title('Cross-correlation baselines of %s over channel at t=%i' % (D.experiment_id,t)); xlabel('Channel');  ylabel('Correlator power, dBarbitrary'); xlim([0,4095]);  legend(loc=0);

ch=1360;
figure(figsize=(12,2))
plot(10*log10(abs(squeeze(D.vis[:,ch,2]))),label=D.corr_products[2])
title('Cross-correlation baselines of %s over time at channel=%i'% (D.experiment_id,ch)); xlabel('Dump');  ylabel('Correlator power, dBarbitrary');  legend(loc=0);

# %%
# statistics in a single channel
ch=[2650,3650];
t=10;

P = abs(squeeze(D.vis[:,range(ch[0],ch[1]),0]));

figure(figsize=(12,2))
plot(range(ch[0],ch[1]),P.T,lw=2,alpha=0.3)
title('Autocorrelation baselines of %s over channel at t=%i' % (D.experiment_id,t)); xlabel('Channel');  ylabel('Correlator power, linear'); # xlim(ch); ylim([70,90]);

figure(figsize=(12,4))
P = P/mean(P,axis=0)
P=reshape(P,-1)
print(shape(P))

hist(P,100);
title('Histogram of normalised powers over the above channels. Total of %i points' % shape(P))
# Out:
# (61000,)

# %%
# phase slope in the noise band
ch=[2600,3700];
ph=squeeze(angle(D.vis[3:-3,ch[0]:ch[1],3])).T;
ph=unwrap(ph.T).T

figure(figsize=(12,3));
plot(range(ch[0],ch[1]),ph,color='m');
xlim(ch);  ylabel('Unwrapped Phase');  xlabel('Channel');  title('AR1 Lab cross correlation unwrapped phase, noise band, all times overlaid');

ph=mean(ph,axis=1);  # average before finding slope
[m,c] = np.polyfit(range(ch[0],ch[1]),ph,1)
delay=1/(.856 / (m/(2*pi)*4096));
delaysamples=(1/(.856 / (m/(2*pi)*4096)))/(1/1.7120);

print('Phase slope in noise band of %s  %s is as follows: ' %  (D.experiment_id,D.description));
print('  %f radians/channel  = %6.2f ns  = %6.2f samples' % (-m,-delay,-delaysamples))
# Out:
# Phase slope in noise band of 20151006-0021  Static test 2 minutes, 30 dBm ch 1360 Equal length RF cables on digitiser is as follows:
#   -0.067506 radians/channel  = -51.41 ns  = -88.01 samples

# %% [markdown]
# 2. Digitiser Phase Slope comparisons before/after firmware update
# ===================

# %%
import katdal, numpy as np, matplotlib
ch=[2900,3700];  # 2900
figure(figsize=(10,4));
print('Henno:  Switch from 12 to 12a happened at 2015-10-14 08:00:00 UTC')
print('Thomas: Cables were not equal length until 2015-10-01 10:30:40 UTC or so')

filenames=['/var/kat/archive/data/MeerKATAR1/telescope_products/2015/09/30/1443625623.h5',
           '/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/01/1443695415.h5',
           '/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/13/1444729458.h5','/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/13/1444729458.h5','/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/14/1444836653.h5','/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/15/1444892523.h5','/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/15/1444894863.h5',
           '/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/15/1444898108.h5', '/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/15/1444900989.h5','/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/15/1444901478.h5',
           '/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/27/1445937477.h5']

# or just this, showing the residual random delays...
filenames=['/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/15/1444892523.h5','/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/15/1444894863.h5','/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/15/1444898108.h5', '/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/15/1444900989.h5','/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/15/1444901478.h5', '/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/27/1445937477.h5']

for fn in filenames:
    D=katdal.open(fn);
    D.select()
    D.select(compscans='~transition')
    ph=squeeze(angle(D.vis[3:-3,ch[0]:ch[1],3])).T;
    ph=unwrap(ph.T).T
    ph=mean(ph,axis=1);                                          # average before finding slope
    plot(range(ch[0],ch[1]),ph,label=D.start_time);
    [m,c] = np.polyfit(range(ch[0],ch[1]),ph,1)                  # find slope (= delay)
    delay=1/(.856 / (m/(2*pi)*4096));
    delaysamples=(1/(.856 / (m/(2*pi)*4096)))/(1/1.7120);
    delaysamples=abs(delaysamples)
    print('abs(Delay)= %4.1f samples  (%s UTC  %s)' % (delaysamples, D.start_time, D.description))

legend(loc=0)
xlabel('Channel');  ylabel('Phase, radians');
# Out:
# WARNING:katdal.h5datav3:Irregular timestamps detected in file '/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/15/1444892523.h5': expected 153.000 dumps based on dump period and start/end times, got 77 instead
# Henno:  Switch from 12 to 12a happened at 2015-10-14 08:00:00 UTC
# Thomas: Cables were not equal length until 2015-10-01 10:30:40 UTC or so
# abs(Delay)=  1.0 samples  (2015-10-15 07:02:11.927 UTC  KEEP Digitiser phase slope, equal cables, firmware version m1130_2042sdp_rev1_dhcp_12a_of)
# WARNING:katdal.h5datav3:Irregular timestamps detected in file '/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/15/1444894863.h5': expected 57.000 dumps based on dump period and start/end times, got 29 instead
# WARNING:katdal.h5datav3:Irregular timestamps detected in file '/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/15/1444898108.h5': expected 150.500 dumps based on dump period and start/end times, got 76 instead
# abs(Delay)=  7.0 samples  (2015-10-15 07:41:13.549 UTC  KEEP Digitiser phase slope, equal cables, firmware version m1130_2042sdp_rev1_dhcp_12b_of)
# abs(Delay)=  6.0 samples  (2015-10-15 08:35:19.172 UTC  KEEP Digitiser phase slope, equal cables, firmware version m1130_2042sdp_rev1_dhcp_12b_of after power cycle)
# WARNING:katdal.h5datav3:Irregular timestamps detected in file '/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/15/1444900989.h5': expected 58.500 dumps based on dump period and start/end times, got 30 instead
# WARNING:katdal.h5datav3:Irregular timestamps detected in file '/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/15/1444901478.h5': expected 50.500 dumps based on dump period and start/end times, got 19 instead
# abs(Delay)=  5.0 samples  (2015-10-15 09:23:18.424 UTC  KEEP Digitiser phase slope, equal cables, firmware version m1130_2042sdp_rev1_dhcp_12b_of after power cycle)
# abs(Delay)=  5.0 samples  (2015-10-15 09:31:28.584 UTC  KEEP Digitiser phase slope, equal cables, firmware version m1130_2042sdp_rev1_dhcp_12b_of after power cycle)
# WARNING:katdal.h5datav3:Irregular timestamps detected in file '/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/27/1445937477.h5': expected 64.500 dumps based on dump period and start/end times, got 33 instead
# abs(Delay)=  4.0 samples  (2015-10-27 09:18:06.280 UTC  KEEP Digitiser phase slope, equal cables, firmware version m1130_2042sdp_rev1_dhcp_12b_of after power failure)

# %% [markdown]
# 3. Correlator F-engine non-linearity
# ================

# %%
import katdal, numpy as np, matplotlib
#D=katdal.open('/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/14/1444838000.h5');     # fine power ramp
D=katdal.open('/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/27/1445937936.h5');     # much longer fine power ramp

#plot correlator power vs signal generator power

D.select()
powerbase=squeeze(abs(D.vis[0,1362,0]))  # get a base power number from a side channel in the first dump

D.select(compscans='~transition')

Freq=np.zeros(D.shape[0]);                # initialise Frequency and Power vectors
Power=np.zeros(D.shape[0]);
ch1360=np.zeros(D.shape[0]);
ch1361=np.zeros(D.shape[0]);
ch1370=np.zeros(D.shape[0]);
ch1371=np.zeros(D.shape[0])
count=0;

for cs in D.compscans():
    num=D.shape[0];
    freq=float(cs[1].split(',')[1].split('=')[1])/1.0e6;
    pwr=float(cs[1].split(',')[2].split('=')[1]);
    Freq[count] = freq;
    Power[count] = pwr;
    ch1360[count] = squeeze(abs(D.vis[0,1360,0]))
    ch1361[count] = squeeze(abs(D.vis[0,1361,0]))
    ch1370[count] = squeeze(abs(D.vis[0,1371,0]))
    ch1371[count] = squeeze(abs(D.vis[0,1372,0]))
    count=count+1;
    #if count>57: break;
    #print('shape %s  %s  Frequency %f MHz   Power %s dBm  startdump=%i'  % (D.shape, shape(D.vis), freq, pwr, D.dumps[0] ) );


figure(figsize=(12,3))
plot(Power-36,label='SigGen Power into A/D')
legend(loc=0); xlim([0,1130]);

figure(figsize=(12,3))
plot(10*log10(ch1360),label='Correlator ch1360')
plot(10*log10(ch1361),label='Correlator ch1361')
legend(loc=0); xlim([0,1130]);

figure(figsize=(12,2))
plot(10*log10(ch1370),label='Correlator power ch1370')
plot(10*log10(ch1371),label='Correlator power ch1371')
legend(loc=0); xlim([0,1130]);

figure(figsize=(12,1.5))
plot((4096.0*(1.0-Freq/856.0)),label='Channel')
legend(loc=0); xlim([0,1130]); ylim([1359,1363]); grid(True)



figure(figsize=(12,6))
plot(Power,10*log10(ch1360),marker='.',label='channel 1360');
grid(True); legend(loc=0);
xlabel('Signal generator power, dBm');  ylabel('Total correlator power, dB CU');  title('Meas %s -  %s  Correlator Linearity plot' % (D.name[-13:-3],D.start_time));


figure(figsize=(12,6))
plot(Power,10*log10(ch1360),marker='.',label='channel 1360');
plot(Power,10*log10(ch1370),marker='.',label='channel 1370');
plot(Power,10*log10(ch1371),marker='.',label='channel 1371');
grid(True); legend(loc=0);
xlabel('Signal generator power, dBm');  ylabel('Total correlator power, dB CU');  title('Meas %s -  %s  Correlator Linearity plot' % (D.name[-13:-3],D.start_time));


D.select()

print(1712e6-D.channel_freqs[1360])
print(Freq[0]*1e6)
print(Power)
# Out:
# WARNING:katdal.h5datav3:Irregular timestamps detected in file '/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/27/1445937936.h5': expected 9682.500 dumps based on dump period and start/end times, got 4842 instead
# 571781250.0
# 571781250.0
# [-70.   -69.75 -69.5  ...,   0.     0.     0.  ]

# %% [markdown]
# Hmm, the script didn't step the frequency along to the next channel

# %% [markdown]
# Investigations for interest, not specifically for a VEP
# ======================================
#
# Constant signal at channel #1024, 2048, 3072
# --------------------
# A quick investigation using available data

# %%
import katdal, numpy as np, matplotlib
#D=katdal.open('/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/13/1444729458.h5');     # steady power. Signal and noise.
#D=katdal.open('/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/27/1445950170.h5');     # fine PFB stepping test, near channel 1360
#D=katdal.open('/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/29/1446100146.h5');     # Test on Thursday am - noise source on
#D=katdal.open('/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/29/1446100793.h5');      # Test on Thursday am - noise source off, -25 dB tone (-51 dBm into each ADC)  NOT ENOUGH POWER
#D=katdal.open('/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/29/1446100954.h5');      # Test on Thursday am - noise source off, -15 dB tone (-41 dBm into each ADC)  STILL NOT ENOUGH POWER
#D=katdal.open('/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/29/1446101212.h5');      # Test on Thursday am - noise source off, -6 dB tone (-32 dBm into each ADC) BETTER!
#D=katdal.open('/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/29/1446103080.h5');      # Test on Thursday am - noise source off, -60 dB tone, noise source unfiltered (set to -20 not -10)
#D=katdal.open('/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/29/1446117687.h5');      # Test on Thursday am - noise source ON, -6 dB tone (-32 dBm into each ADC) CORRELATOR UPDATED
D=katdal.open('/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/29/1446121000.h5');      # Test on Thursday am - noise source OFF, -6 dB tone (-32 dBm into each ADC) CORRELATOR UPDATED

D.select()
D.select(dumps=range(3,30))

rge=512;

Pwr=squeeze(abs(D.vis[:]));
print(shape(Pwr))
cols='rgbcmyk'

figure(figsize=(16,2));
plot(squeeze(10*log10(np.mean(Pwr[:,:,0:2],axis=0))));
xlim([0,4095]); ylim([0,15]);  title('Spectrum of the whole measurement, autocorrelations only');  ylabel('dB correlator counts');

fig, axes = plt.subplots(nrows=4, ncols=int(floor(4095/rge)),figsize=(16,7));
for a in range(floor(4095/rge)):
    for b in range(4):
        axes[b,a].plot(squeeze(Pwr[:,:,b]).T,color=cols[a],alpha=0.3)
        axes[b,a].set_xlim([rge-11+rge*a,rge+12+rge*a]);
        axes[b,a].set_ylim([-0.02+0.9*np.min(Pwr[:,(rge-11+rge*a):(rge+12+rge*a),b]),1.05*np.max(Pwr[:,(rge-11+rge*a):(rge+12+rge*a),b])]);
        axes[b,a].set_xticks(rge*(1+a)+np.arange(-8,9,8));
        if a==0:  axes[b,a].set_ylabel('%s-%s' % (D.corr_products[b][0],D.corr_products[b][1]))
        if b==3:  axes[b,a].set_xlabel('channel')

print('\n\nSpikes seen in %s - %s' % (D.experiment_id,D.description))
# Out:
# WARNING:katdal.h5datav3:Irregular timestamps detected in file '/var/kat/archive/data/MeerKATAR1/telescope_products/2015/10/29/1446121000.h5': expected 301.000 dumps based on dump period and start/end times, got 151 instead
# (27, 4096, 4)
#
#
# Spikes seen in 20151029-0014 - Test of 512-channel boundaries.  90s, 855 MHz -6dB tone, noise source really OFF, CBF updated

# %%
floor(4095/1024)
# Out:
# 3.0
